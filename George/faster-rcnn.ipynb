# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/README.dataset.txt
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/README.roboflow.txt
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7dac7803-22f6-4399-8f05-ba4543e3af8d_png.rf.0cf9082145c0dabd2349b36f594d109e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/empty-modern-hospital-room-with-oxygen-concentrator-modern-medical-equipment-in-the-intensive_png_jpg.rf.2e2241800663d288f8ada183e44047eb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test21_jpeg_jpg.rf.6971e3c7d57940f80fdea60322e140e7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-403_2022_5_18_9_20_0_jpeg_jpg.rf.b7eab5e55909484d92fc2af0c974269c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4fc8de61-884d-4ea3-ac5e-eb7c737efa3b_png_jpg.rf.4ae309ecbfb762730e708b59f7a6a82a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Wooden-traditional-design-corner-sofa-set-2-1_png_jpg.rf.6a9828dda050956eb7474c9b21041fcc.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/9bbf017a-e01f-449a-ae3e-4f06aa844836_png.rf.5145fd6695883085092575c7e95018b6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/empty-post-operative-room-1-_png_jpg.rf.59b2d561497a8d1b1d06fef923c6b9fd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/b7d25f48-d205-4b7a-98a1-447fdd394ea4_png.rf.3c92de841f44c754875189ab90efd003.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/f4c3f96f-eaee-49aa-8f0d-269ca9f8d5b7_png.rf.1b66587a24d304c0299180d60afdf0b9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bed_8_jpg.rf.8da6e165152700301c4f10e7609a5a7a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/9f4a24f0-4652-4fab-bdf7-cd84b5f6be75_png.rf.7b9a609e1b19d0347091f0d0e28f26df.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test38_jpg.rf.b67e622f931e08427b7afc48821c7a2b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7e429c48-38cd-4789-a6bc-07cc79dc253a_png.rf.b6cfe2e5a1aeb5baaaad314ad25d5ad6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/500_F_961683105_NhQFMrUJjpILY0aCuWGyofG2wbQrIhbr_jpg.rf.d0db2067ca2a6001b10be90b3d23b0e9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test16_jpeg_jpg.rf.5b516ef25fba59c52eb9f3387f7fbf0c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-38-_png_jpg.rf.f97a457b5637a2ca12ca0b83a7d0bd9d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test7_jpg.rf.aa4676ebf01e10afba12e39cde8810a9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/76504b39-a1a2-4d6e-92fa-5cc9975fcea1_png.rf.48cfd61b92386c06aa28987fda043896.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/c0366521-a62e-4c87-a694-e0a20266c471_png_jpg.rf.7d34503d48f5b63f198a503ccbbae036.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/87419687-68d5-4891-a3c8-0b097e4a54c9_png.rf.442d7a4b353798c076317239198b9245.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/e55908cd-533b-4a34-b22f-3a725a58ba41_png_jpg.rf.d0509f358a0719dcd35ff313a696a7fd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/dfbd58dd-1c19-4614-9df0-0451f0e1e820_png_jpg.rf.da8bec8ac4f8d05c5d08065724fab2ac.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/af41c146-4c85-4d33-92e2-351e4a02080c_png.rf.125ce70f11d59da9617cea51bc176a06.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/data_2Ffabric-sofa_2Fnew-osbert-set_2Fnew-logo_2F1-810x702_png_jpg.rf.aba26d6d9cb55a53089096586e38f2db.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/fa28175b-37ac-4ad7-908b-7a73a403949b_png_jpg.rf.d9df4b23f6cd4b68761d2b2dba8eadce.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test70_jpg.rf.264ae9cec882c6bafd47c745645a5199.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/80d15981-358a-4099-8679-6ea3d96c193e_png_jpg.rf.c6122cbe5cd005fdd42cd2c25c7bda28.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_6_20_22_30_35_jpeg_jpg.rf.ae937f6382690eb59c43cfa262a5c70f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Sofa_03_png_jpg.rf.1e1a181b2448a3a6f0b5c9fa4f0e6213.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test4_jpg.rf.774d27cc499507cfec8fba7225e9ad7c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/jo0nfcjnd4wdmicq72vmaaz3994os7h3_png_jpg.rf.720f97c8937ba45b730b115be6fe76aa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/b85dcd82-1fb0-4e14-93ea-1fa1997506e2_png.rf.574b2ac7426831ed0ea23340277d404c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/grey_sofa_price_3s_png_jpg.rf.3ce5f7326c18faea6e943c9d4242a405.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/c9de2dbf-692f-44b9-80a7-a3e5e3a9274c_png_jpg.rf.af6d1cbdce0ca04eda3756473351f50d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ECG-1-_png_jpg.rf.6757c6d300d9a78a94b2b48ff68a39a8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Rebecca3strLsfront_png_jpg.rf.9a74f2238a6aaf39001dfc8fa444e16d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/98e0454c-4a21-47b9-ad77-e85c0acf0568_png.rf.163197ca5abfa4216daeb5f0d116ab63.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ca5eb759-0a5e-4fd3-bc4e-3a253033e04f_png_jpg.rf.e702c5908804a04f821213d0bf7912e1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/kamalnayanbajaj_micu_mon-15_2022_6_20_11_46_34_jpeg_jpg.rf.d4a72aa73e4bb3b7a6579873e0458720.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4eb1597a-02ca-4062-ac9b-5ae90411c5b8_jpeg.rf.b190c74e13bf7a8f2ebbbdbc385595a3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ECG-14_jpg.rf.1e062ea137960f1577114726eece75c6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/d91ff927-f257-4ea1-b841-40dae7f69915_png.rf.1950c4cf1bc325f9c34527b36a6517cf.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7f7f938c-d3bc-4365-960c-01c9335bddf2_png_jpg.rf.8d760419f8242bb91f18a239583b7612.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_847997642_DkLlzR9LfhhdbHV1HXWzvB4aVW1y4RJv_jpg.rf.e7c77256d8240009bfe330bcd364ad27.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/85ccaebd-3ea5-4efc-849a-d8ad953a79d2_png_jpg.rf.49c63cd517d9a6d264eaa3d71023192d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110206_jpg.rf.e60dfc24e0133df6285b592f4ab4aa87.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-406_2022_5_18_2_20_24_jpeg_jpg.rf.1d84c3a05bc86528e6edbfbd9f76bb06.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/89a192f2-dd09-4b35-b7a8-649d82f12b8e_png.rf.5fe9a6d69ad9b1daf487f88a916590ab.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/baadd884-a341-40c2-8fff-f3ce3e3d2649_png.rf.dedc7744fa10449a5e405257445a81ed.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/5f65a41a-10ee-4f16-a6ca-0c42d07f7d24_png.rf.9a1e704da9722e6533e4de91536e047a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/52bb5fb0-ca8b-4a96-95a2-7e15a0229540_png.rf.589a0c809843c6da833af342625fca35.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6080af3c-f18f-4562-b359-5d20c6f0a540_png_jpg.rf.537f969640f123aada41464fa2a401fd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/operation-theatre27_jpg.rf.1143b74facfe00addf17b616867476f6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/466fc857-8a70-4006-b681-5712b36837e2_png.rf.ce37dbc82c9376236c804803cd7b8376.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110600_jpg.rf.6d3f3662a5dd1376fd173cab67a0a4f5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/e7695002-a071-4bf2-9f5f-7fd2d82a4890_png.rf.a27b16867ae7e1fb3614d0ae2aa90520.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/wooden-sofa-designs_png_jpg.rf.6f8b7141765dd344e18aebefff827721.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/5b992148-96ba-46e6-853e-e03d4f869da0_png.rf.89f1bd3b924fadad731b16b29fb0099b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/133b384f-5a70-46cb-a44c-bec89991e6e0_webp.rf.cbbac2d3d5393e96525b41ce4ba77290.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/f5fc34dd-1a29-4be8-887c-2e4a3274c3ed_png.rf.e02429fcc8a0551b6cd8a660b127a3b0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/13410164-df88-4bd9-b685-a936e40caf66_png.rf.ee1894ede38cc67e26f1331338d4a8c9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/57e00561-0bbb-41eb-9b32-f63d030d169c_png.rf.b11906e93b5c311cd905afea4c67ea48.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/37a3c9c3-46e9-49a3-afee-35012464d09f_jpeg.rf.0c236ac08fac2a941986051cddc396f3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-9-_png_jpg.rf.222c2a76176063b7d35cfbf6ca0e1fc1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-46-_png_jpg.rf.5296ea28c6f1fcc7b86b369a492bab77.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/LAKEWOOD2strLS_png_jpg.rf.6f817d40cea220f520337e7194a31c8f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-2_2022_6_20_23_30_13_jpeg_jpg.rf.cb3003e0055a3e50295807926a235b04.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/appropriateforcare_png_jpg.rf.c60b54257e7e98f9868fce3fd15a642f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/47f588e0-6424-4490-8022-a4c4706a75ba_png.rf.0d274edd01ed4bf9aae8657e6c2ab64b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/321999ab-83d1-46d3-8ccc-de214565892a_png.rf.b5af0597c134912e513f3031729af265.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/541f1615-5938-46c9-9451-0653c024a7f9_png.rf.3dd96542cf5830bec5e0768fad7f6844.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a5afeb09-47b8-4c54-9bb5-3b9f6cc191e9_png.rf.ae881779c12388092bda2ecfd1c8e46c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_6_20_2_30_24_jpeg_jpg.rf.969db32720680ca7f7f3cfbcf4ee6b13.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Sofa-Pink-FV_png_jpg.rf.b95b8f258c59ea01d74374fd6d48a904.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Epiphany_png_jpg.rf.d2da5d393041981c701375a33dc3b9f4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_5_18_10_30_40_jpeg_jpg.rf.fd3ca79b1b442ca7f4e29c5a6d9c845c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ff1e767d-81c5-4da6-bbd4-d1c406475e4e_png.rf.df860a28ec577b22ab5c61213ad19c71.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-33-_png_jpg.rf.bf255caedb0d602b6f3369e0d34cacfe.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/e118a527-fe4c-468e-a8cc-4ed664ebe8fe_png.rf.fc7d495ea49bf0fbbb1e94e1d729f5e5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/comfortable-termite-resistance-four-seater-wooden-sofa-set-for-living-room-808_png_jpg.rf.9f01927aad84224091af864e0b5393a0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/774b4eb9-0780-47ae-85ba-1d62d4f9ca6a_png.rf.6b8f300ae9e1ce16f7d2e7f96f0565cf.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/73df3763-3a37-4e37-9314-af3d504a7951_png.rf.599bc37a27da86ea011725a96acd54af.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/modern-hospital-room-with-ventilator-system_png_jpg.rf.d04500c2cd0c69cda02b0b143f3b117f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-42-_png_jpg.rf.80afeb1238df13697dfd8e55e0305d10.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/283662f2-a4ff-476a-861b-4a67d268633e_png.rf.88f2fb0bbfb1cd2e197602770730cc10.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7ff76f24-882d-42da-9ae6-31ba5f040e94_png.rf.cdd8d0968aac3396f70aa26720aff827.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_47_jpeg_jpg.rf.d1e0b8879193af96de0c4255c39ff66d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110635_jpg.rf.9743161283b967550170000d9b0abbcc.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/335558137_png_jpg.rf.9b88e25dffc155a77f59dc49c299b329.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/2598bcba-1863-4507-85ae-e1881a3e224a_png.rf.ca9d41e7e81e58a792cf373bf8e6d4d5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/3d098d40-e0d1-45ab-b3ea-b15accaa6837_png.rf.3d1f0694ecc7d2d0d7b72335568e2d3e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_25_jpeg_jpg.rf.de8159388c954a736f4922d497c1f82d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/jtxskrl3duik9nge5lglpxz7d4ucdthx_png_jpg.rf.5777a6389e930f1bcaef4a08ecf2d2f7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-8_2022_5_18_23_30_52_jpeg_jpg.rf.52f9ba44bf46871d757a367f9186f0c8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/fe989f1d-6599-4c3e-a467-fb00ec615075_png_jpg.rf.91087f52312fde4a4e3d9bc163af4844.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/fd0938aa-5bcd-4b7f-86d7-e2e95746b247_png.rf.710766bc9888c2e348299abf24f88438.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6c63a74d-942b-42e2-b56d-dfece449c385_jpeg.rf.2ae9396d6146d73889c3b0e746ec4935.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220804_103930_jpg.rf.2f86565d7d975d684434054b118f3b17.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7048d623-2754-4fe6-bc51-bb20456ed951_webp_jpg.rf.3279d9277a030928f94656d7b8a927e1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/2ae10401-74df-4954-af0f-3f0cd023dc1a_png.rf.9bda5c3772986ae61ce8c39ce762fcce.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-2_2022_6_8_4_30_14_jpeg_jpg.rf.50ff4334667de16e42e01cb4c7347f85.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/59ce7207-7ef8-4fc5-8c09-e3d18966c87f_png.rf.c516643617f40c2b30953d528cb5e642.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6_8f671207-a211-4c04-a3a6-9b0887455b39_png_jpg.rf.e95fa819a46a9f89c1427b7ff8667b5c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Screenshot-2024-08-27-141100_jpg.rf.1ca114862eff78d0e3de77cd6a8965c6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-7_2022_6_20_0_30_58_jpeg_jpg.rf.b5f2504288eaff4b95c89cdf19c31983.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/964a9a67-ab33-476f-9ba8-5279bd3d4166_png.rf.0fe87ec0bcf8ef997b0266d19eb06e67.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110144_jpg.rf.2a97505516007e26370bdc47a9868e7c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-8_2022_5_18_22_30_54_jpeg_jpg.rf.87c3d654aeec03176f3513bf5f4c845f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/1c19a766-054f-46b9-99fa-9ec5063bd56a_jpeg.rf.cc6c36299547bca58a0859abda951d67.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/37a5648a-40e0-4fe1-a122-cf43c07802e5_png.rf.11b549a25bc69276cfbec5805d3f84c7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_38_jpeg_jpg.rf.57d8d16b27550afa66e7e56652b598a1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/l1a2llqy8opb59bql5clidnncl4tr556_png_jpg.rf.0b602eb45a3b86cae22ed2f189d7cb77.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hospital-room-with-two-beds-in-blue-tones_png_jpg.rf.5934ca57e13a1990c39eea5ad6021590.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/5345a459-d87d-4f7d-9e31-9522e7f6ac95_png.rf.7f37d3781b242cf1565b4562c4d33996.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_5_18_17_30_14_jpeg_jpg.rf.933da7bb42e4ea33719fe5ccacf86829.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/b2f87f08-6330-4fd2-b5d3-2f8a53f3bfeb_png_jpg.rf.cbb435664a966816dea0102bfcebaf63.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/operation-theatre12_jpg.rf.7b65aa8cc7bb94b563ee3b88949790a7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/039cc1b3-f387-4618-979a-cb3979d0ff54_png.rf.ffe2a406e6732907dfb8c336ad701727.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test41_jpg.rf.a38fdad50f5cb1797391db59edd4c7e5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/k8tjxakroocah25v4y96k9qh939h9cgv_png_jpg.rf.15974767f5988c48f8299326c538e0be.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/WSFAFLPN3FWGR_LS_1_png_jpg.rf.444dcf049d3e95bb04c7786bd629c49a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ECG-6_jpg.rf.e1a1224e4630b04296dee5221fd60dc4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/684e1b763de93aac46e8e038afcba540_png_jpg.rf.db795e3374861e5e80490a01c33e0f98.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-403_2022_5_18_13_20_1_jpeg_jpg.rf.b4150f4c8e13b52db745266ec5a58e3f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/41pytIxPKxS-_AC_UF1000-1000_QL80_png_jpg.rf.3535663ead174a3f46a769158c0f2168.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-55-_png_jpg.rf.1f014c329fb7b37586ad4528eedf92fa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/soft-focus-background-of-electrical-adjustable-patient-bed-in-hospital-room_png_jpg.rf.a60d3786813e525ff2644126e130d883.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/sofa-isolated-transparent-background_191095-10347_png_jpg.rf.593981b3086adecab1e9299d483851f6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ee418ce1-1320-4505-ad3b-7b1bee0c1e8f_png_jpg.rf.2bb173822064e93c52f4e482445c11fa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test65_jpg.rf.95fcee17eaf1d7bbfd09b869dc2c5d4d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a-hospital-bed-in-a-multi-person-hospital-room-3d-rendering_png_jpg.rf.44a28152d5cf397617288422ebe02e0f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test8_jpg.rf.e9fb44c935f9adfbc18ec7bbd094655b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/kamalnayanbajaj_micu_mon-16_2022_6_20_3_46_46_jpeg_jpg.rf.54481ec1b9d8b87ef13ff84e0ee54ea5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-2_2022_5_18_10_30_14_jpeg_jpg.rf.3757021819024ba8b60efeda6975ccc9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-19-_png_jpg.rf.e485703bf630bf1d2a974636e5dd9289.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bed_2_jpg.rf.ec4aff612307730587b612e89e4a2aee.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_27_jpeg_jpg.rf.df13280fd523407a65ac15a84835502c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/05fb279e-1566-4d47-b036-f1dd15b30bc4_jpeg.rf.63afe230cb94c2eb1b980981a00bfaf6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/room-in-a-hospital_png_jpg.rf.b55d67c76751f6e949e3bf741351051d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220804_103828_jpg.rf.3befa050c73ee6e59415bdff30140590.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/gammalbyn-3-seat-sofa-bed-blue__1187046_pe899026_s5_png_jpg.rf.845f519cc781c4332ca092ad9f78d5a3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/data_2Fwooden-sofa_2Fsaket-2-seater-teak-wood-cane-sofa-sand-beige_2Flooks_2Fupdated_2Fnew-logo_2F1-810x702_png_jpg.rf.9453aa520bb32e368649af6728613cc2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/752113ee-c7f7-4750-882c-29cab630fc7e_png.rf.8351af74200ec2c3ad5f11c533ebb272.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/left-facing-velvety-grey-cotton-no-bliss-e2o-trevi-velvety-grey-original-imah2d9xffbkyzeh_jpeg_jpg.rf.3c35d4524c9c6548a1ef34c8f0bebff8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/image150190_png_jpg.rf.7d6c61fb477242a9fe7885cc1ebec137.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/04078e34-bc12-409b-8f55-9ba96fdcc110_jpeg.rf.e2c68d4d1aa5b43e33c89cb652620b25.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/85816e30-0d54-454e-9750-098020ca4e8e_png.rf.40ac684085803a476c2b9f4c14ddaa75.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/8f125d75-f4f2-4a93-92ce-3b64c582acc2_png.rf.a85253192080eabea874274514d603a3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_768316888_O1fInmZNrPH13cn7gd6jynG4Y2NfdLVI_jpg.rf.d9d6095f7849ce6efb86974cd15ea78d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Apollo_Infinite_FNSF51APDU30000SAAAA_slide_00_png_jpg.rf.423f0263b474a32b15a63aaa3a37ae51.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test35_jpg.rf.981f6961bc92d3530400bf14160b9cab.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bed_15_jpg.rf.5bd9500348c11f244100136f0314730b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Screenshot2_jpg.rf.be65b0f2d47dade1dca2d820cee76436.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/FNSFBD62UG36094_LP_png_jpg.rf.cd4ebc323d392ce1935120e13354c958.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/602d815b-6389-43ea-89f5-36cdadb6aa6b_png.rf.3df8d001d621e759c83814601faa8de5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4b3dd055-2f37-40dd-90c4-e70ef4673f23_jpg.rf.be8c463c2fc85afbfe58c722a418a9d8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6x6darkgreywith2cushions-01_e61a8653-1531-4cbc-b687-18f3622a3862_400x_png_jpg.rf.b4bae58ede2c63fa215ff452976b90a3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/pic-hotel-apsara-near-jj-hospital-mumbai-21-1-_jpeg_jpg.rf.b2115a1934054e678c4fa6c1acd1a4fb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/gammalbyn-3-seat-sofa-grey__0868928_pe781439_s5_png_jpg.rf.835bbf8d626fe067eba1b2b27e7a9a38.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bcbaebcf-5e85-48ce-a6b6-b318333260f8_jpeg.rf.12e2928ca7d804f6ee0118b183508290.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-5_2022_5_18_14_30_26_jpeg_jpg.rf.6a459416797bdc95b82f8b8117b8e93f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hq720_2_png_jpg.rf.2d5b02dbf093fe468845e49c0408ef3c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/8bc7419a9dc59251370141b75a328eab_png_jpg.rf.4410b76e2f6c99d25e6d6ae12b994d51.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/kamalnayanbajaj_micu_mon-13_2022_6_20_6_46_12_jpeg_jpg.rf.082597f796efed49eb23e387b6066c65.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Rippon3STRLS1_eb2bda5a-b28b-4d24-bb27-848679ab65af_900x_png_jpg.rf.7a01f7d399f804aaeca253bcc1fec6b2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test60_jpg.rf.28672e0c16b0a424b438324cb827f838.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/electrocardiogram-hospital-surgery-operating-emergency-room-showing-patient-heart-rate-scaled_png_jpg.rf.fdfb38912430ae17c96d01614cd28329.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-403_2022_5_18_8_20_0_jpeg_jpg.rf.f1380c8213642e5c0fce18033aafe4fa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-31-_png_jpg.rf.b82eef1eeb9c0c780437215f328f6b97.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_31_jpeg_jpg.rf.8b66d494702914225a9c527be9fa6bb4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/3b5xp4kpsul8h42udl2dryeqp1bn140c_png_jpg.rf.6f9fd97915eb912fffbe8c0224f18ab8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-404_2022_6_8_1_20_0_jpeg_jpg.rf.79f41155ae5563e68369613f68bf4421.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/249c9402-5d69-4364-b2ca-65d9293aea01_jpeg.rf.f4427db44077a5b2d1a5047ec310f086.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/da7d6fd6-8ae4-427b-bbfe-2d88e7561d3a_png.rf.d2d665998a2e732e64878f6624e85643.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/86c3ddb6-ae8c-4f85-8a77-102c24d5ce91_png_jpg.rf.a19e95fabf8ca45d624ea3738ab72143.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_752495618_xUSLvyIAvw0F5iN0ee5TnbuBV5qDzRCL_jpg.rf.4de053ff74309d707b590b2b9ab97f57.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_6_20_0_30_24_jpeg_jpg.rf.f5c612524ac4e490a629ea657c9f63c9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/kamalnayanbajaj_micu_mon-15_2022_6_20_23_46_20_jpeg_jpg.rf.a7273839dc7f17ad0bb55edee8ec6f54.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hospital-bedroom_png_jpg.rf.9beda49a5402d6f8f54602041941ade0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/sofa_WSFABLZPR3CFVDO_1_png_jpg.rf.84c73a31888bfb98dddbb52717e698c5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4858f493-dfd9-47a6-b536-47552c657cff_png.rf.e04929ab417e1b8941301a4e50c5ca1b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/aff15153-8537-46f9-9c83-7a05adae15c6_png_jpg.rf.3ec2c982289ab40edd9891ca485ec7d8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/41b162d5-d0ac-4d8b-8866-fc00b85d79fe_png.rf.f00b4ad13d351c2b4c3e937bfb4d246f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/empty-modern-hospital-room-with-oxygen-concentrator-modern-medical-equipment-in-the-intensive-2-_png_jpg.rf.e7f311c71ce7cc2adb7df4ab44f0ddee.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/_annotations.coco.json
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/199e91bd-ffac-4eb6-8739-84d7d86f9c97_png.rf.40e8c4435a0f32a49535f019360222a3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/fe1a1557-fae1-4278-9e9f-04fc55e1327a_png.rf.76d30e5343794a98459c1bfe38b430f8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ee5d09c3-8858-4ed6-a92d-66ad58eb9a05_png.rf.3fe865a986e1e2e9a4da90c2b2ca9022.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4thaug_2ndhalf5934_green_png_jpg.rf.99e234a2b2c630cf7e5b82bb046b3a29.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/c5be129c-5823-45cf-8f81-0a8ee2c8cdc7_png.rf.1aacabda66a647a600854881aec6d2d1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/0d26b45e-86e1-40c6-aa7d-749a743c9fb1_png.rf.e170f831892c66d421a3ab600762ab06.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110133_jpg.rf.4d634b0bd00d4142ea865723f32e3907.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/91267394-e356-4cae-be80-177f9003c464_jpeg.rf.cbd6d999da689a2dbc00c9263da868ef.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/gammalbyn-3-seat-sofa-grey__0868929_pe781437_s5_png_jpg.rf.90afe1846235168c38e7b00fc253fd6b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/75fe851d-b207-40d6-b181-4a673bc0c530_png.rf.2c893e8d4277391eeeee8837bb8da6aa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/canaryyellow3seater_png_jpg.rf.57a24caba2d1e716b30bb37a90b88389.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110147_jpg.rf.e3284ee39f130278e4bddfe48fb47272.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bcb5d745-5b64-4715-b764-5d8f64ad0509_png.rf.b282e9c640a313c186b87f7828de5e61.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a1c20858-ac34-480c-b68e-3f0a7b73cf36_png.rf.49e0b6565605747a6f38cef743074532.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-13-_png_jpg.rf.3e418b3aef88cdaa5e1e1e147631d4e0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/pexels-photo-1631918_jpeg_jpg.rf.75016e7ff0fff7efda48d3ad84e4a9e1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-15-_png_jpg.rf.c488f7284f9cfae71f28257c675ada5b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/d3777b9c-5c86-4407-9f3e-7e9b84417845_webp.rf.1a471c0086f16effbb6daff863a4a269.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/426j2cjm2gmqrqj6wrgvegndcctzlahx_png_jpg.rf.56444efe433f13483bc6e5cb4c70d548.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test30_jpg.rf.43fae6348f4fe5d6223a017f85f16aec.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/fe8210a8-86ef-4c86-af40-10f5a3fd7213_png_jpg.rf.c5ca5a84f7f82ed56cc6da0bf3928614.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test37_jpg.rf.1ecdd521c2e6f4c12ab3464903d28955.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/f38dd7c8-aeba-4d4e-868c-a45e223c5d76_png.rf.38d907b6455dea905ade7e1bc0843979.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220804_104020_jpg.rf.b81a5b6f7bf67d34ed2b0ee75aa01e6f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/intensive-care-unit_png_jpg.rf.7895dda527542dadbba8834668b3371c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/519066a8-36e5-4db6-89ef-1525ad5f0dcb_png.rf.5a63beb11ffb59f4d8d231576cdadcc9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/bed_13_jpg.rf.3de96d7c177832572ee3d19029a909f0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7978-1_png_jpg.rf.3021c173ba41cf01d97ad4aa7d01a670.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgbhavnagar_micu_mon-403_2022_5_18_10_20_0_jpeg_jpg.rf.95bc1911b552e1eaa03cb2ecadd2a2d8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/9dea068d-e6a7-4267-b704-5a0dda218e73_png.rf.bca3b66277946b70513e28bc68a01d9b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/f5f01cb1-8668-4223-884e-489e8cbc9d9c_png.rf.9f47665125f4de1d1df467c41bd6d0e4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/52553b5e-03a5-4cbb-b695-f149f743ca1e_png.rf.e37fbb0a8c56020c79ae568827ebf46d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/kamalnayanbajaj_micu_mon-14_2022_6_20_1_46_26_jpeg_jpg.rf.a608a8bd510808bd17b7a7852ede8c06.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/1b0b7384-e187-47cf-af74-de69625db78c_png.rf.b8f5d43dbf0955886fd0dbba8da672c3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7d422a26-36e6-4184-a693-0ccaa2475810_png.rf.151530e22b2b9a67a69e9c9786406402.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/images-14-_png_jpg.rf.465e65909e908ee69f9403aa3d8dd417.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test31_jpg.rf.a26a3a5ce3497e96d4dc8851cfb968a8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_892275794_Qy3oqRFLKReol1mUFSXx2guuYQHEmUUL_jpg.rf.f0b21d84eff07bdf5a66f39aa8259ee8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_891759652_2WaYsBYyPI3cqGFbpjuJPT2ulEffj8rb_jpg.rf.9e00b9857a5e1a44a0825b0249e04c4d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-2_2022_5_18_3_30_14_jpeg_jpg.rf.c54c28f046b281c8dbc542e24d3b9596.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4thaug_2ndhalf5934_blue_1_1_png_jpg.rf.8c9b679c7c8455534e6fdee4aed1ca2d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/flsfhayly1strmbwn-jpg-f51bcd8178-989xx_png_jpg.rf.4d19dd45d7e98c3ca12b6729e69f5e49.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_6_20_7_30_24_jpeg_jpg.rf.c5059780fd7dbfcca87c0cdab1ffeb3c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Lewis_Sofa_FNSF51LSDU30R00SAAAA_slide_00_png_jpg.rf.c1361c2de39d6a8eca03508a1ab433e4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_5_18_9_30_40_jpeg_jpg.rf.2dc47ccad78d00b208d8b5e4df6f19a9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/42087240_png_jpg.rf.3ac5731aaa2cd665ee56edc7cebaec1c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test59_jpg.rf.04230a0c95865ffad23cc9b8a50b3efa.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_49_jpeg_jpg.rf.e64105466c5f3c76f8c36b3d3f921a41.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/3b539141-8763-4e1a-8b60-899592779b59_png.rf.c8dfb24b4b18e337ef08917b00802d6d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/minimalist-sofas-in-singapore-simplify-your-living-room-style-megafurniture_png_jpg.rf.d7d28feaf6dbe946c0821c84b9600f03.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/teak-wood-sofa-tsf-2701-timbercraft-1_png_jpg.rf.d353d0b6990561634f66ec7a1918ce92.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/e1a7d6f7-369e-404a-a59e-3e0a2e9659ca_jpeg.rf.f8c380fd0116f3ab74d3a2cc7f01fc31.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/360_F_649019465_69A7AUi0eAEPKkcVxzAmpFStWZckEGXh_jpg.rf.58665f88d303802a6297b2a3c9f74c18.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6ef81718-34f0-4ed8-a234-6197b7f4641f_png.rf.053f781ca76efe81dbd9802d10ebfd91.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/633fef24e2cf6b668f0349b2-black-friday-deals-2-pieces-living-room_png_jpg.rf.0b3efa51e30a3d33df685078638506d4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/6d103395-24a9-4ec3-a2d5-137a7d0e14e0_png.rf.86eaae3b5a031d022c7fdc3fef1f14ec.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-4_2022_5_18_23_30_14_jpeg_jpg.rf.1225175a16eb86b4f82fabcf159b5a52.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/operation-theatre25_jpg.rf.cc5fe016bc936d897f6faf8834bd9658.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a-maternity-ward_png_jpg.rf.536b82fb74cda61847aa5630056d2195.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_40_jpeg_jpg.rf.85597316428c0187a7f10249001a70ac.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Felicity_Sofa_Cum_bed_Color_Graphite_Grey_LP_png_jpg.rf.3ac04368e26ae8f0d36a59625a0f6eff.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-7_2022_5_18_22_30_42_jpeg_jpg.rf.35827a17a0636fc043a2afb01b1282db.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/leonardo-2502290-176679035-832338_png_jpg.rf.d3e4591c2aeb8ed45fc921445a3c53e5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/oyo-premium-mmm-hospital-1-_png_jpg.rf.3fb65a6952f4fa0fa76541e80746f6fd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/hcgnagpur_icu_mon-1_2022_6_8_21_30_1_jpeg_jpg.rf.2b9dd002994a90bea0ad966afd72f608.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_test26_jpg.rf.413f41208b2f88e2be8e1e8a703e2d7f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_16_jpeg_jpg.rf.524369ddbdfa09c0385ae6ccce0ad5d7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/boston-small-left-hand-l-shape-sofa-rust-364053_png_jpg.rf.a50e96aa6fde8d472af35895df0e4ca8.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/84-0-black-na-3-1-1-187-0-88-18-11-0-mayur-sofa-125-84-mayur-85-original-imahycru7mhpzzny_jpeg_jpg.rf.265b768a2a93acfc8a3082d465bd2af0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/e83a0bd8-3fae-44b3-b00a-e947e77455e1_png.rf.6ddecc7d78d7afaf6d5dade300c9c811.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a0b1549e660a925150642577ce986ca0_png_jpg.rf.ad3d2736bed0815c683b53d7f803a8ff.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/1bf46195-883a-4333-8b55-f4ae8e5b8aba_png.rf.bbd7ed77e7e78a0c8a844071ce414fbb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/intensive-care-unit-1-_png_jpg.rf.8bd756e7b8ab4c3c8f06debfd9df1966.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/2caa69fb-0f6a-45b5-abf8-3421be23d887_png.rf.00d13d30440673454b8044eeed5b9576.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/tool_9_jpeg_jpg.rf.d790c958bd99d3aafc54c4722bda848b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110211_jpg.rf.752fff093606823c42e88d449826d690.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/8b97a418-ff04-4e6d-82ee-d1b0f6e08170_png.rf.8d036740530323192a83c0f542cb7c2a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/medical-beds-separated-by-nylon-curtains-inside-a-recovery-room_png_jpg.rf.a5e661168292a16c43ebdc8aa73d3154.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/1e96003c-5399-4b0c-bb0d-95feb428f341_webp.rf.243874cc0646a19ea766fd926dcce207.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/7d2171e0-15d3-443f-95ed-f22e5843e15f_png.rf.1deb2b499ee49a7147cb402820ccca26.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/22609c09-42f7-4805-be68-13c61d05baf2_png.rf.eb6ad3863a3e663be2a7accf2603dee5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/a7caac70-5cd8-40ad-b4dc-1a0d36004a96_png.rf.40528ddb9bb21e9d120df736b15348a5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/Screenshot_hospital_jpg.rf.ba194805310602a27b774489a8785dd6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/IMG_20220803_110212_jpg.rf.9fbca832ee1a45e6771da7438f39fc42.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/ef97c74a-13e8-4f9f-b969-492b8e91827a_png_jpg.rf.11742166bd8410a0d3418261757c5df4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/operation-theatre13_webp.rf.c0d438fed0c6d577bf9f0b36e1c870b9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/4a5c4a09-dc17-481a-8fc4-32d6a9f9ad2f_png.rf.b1ff00e3fa742f36d1a303bbeab710c7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/2da21ae6-8b67-4ae4-934c-5da10ca58a17_png_jpg.rf.699c49822ee817b440b0de9298e90c35.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/bfee2ef5-6a2e-4ea5-9718-21c787c850fe_png.rf.b46d7ce18db9712378f3047bebeb3514.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/e32205dc68687f0f-1-_png_jpg.rf.8dc9ec41e617f19b0285903c929d3431.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/buy_sectional_sofa_brown_png_jpg.rf.2c3db139a5bed3874c01ae5dbd9a710e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/tool_test42_jpg.rf.1b4342302002321199fcad98849b9dd9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/leonardo-1113071-Standard_Double_O-174521_png_jpg.rf.bf414680f56be53cbb0593ba11e84f68.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/2-min_2904e1c4-c080-46c7-96b3-8c6f17c4aaa6_png_jpg.rf.ac86a77ed8eceadcac85263f50af4da2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/6e11a7db-e1a0-4590-be4f-a7e90a9dbc6b_png.rf.ff6f154cf967a64de8f825f4abebb18b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/6f8d7936-c684-46ba-8c7f-4c12b267a558_png.rf.2c0e13745393a2eef0264a80c840d392.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/06e6ebad-0347-44ce-a664-954f26dca089_png.rf.73093bb2be1d92491ca949b8727903ff.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/f5397e0c-5143-4222-9360-713288d664ed_png.rf.ed35526c6e58d3fd31e89a141cff1410.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/c79d25b7-c26a-49d9-a85d-e434f7864471_png.rf.25d2df73afdada371cfc3ebaf05306c1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/c78dfcaa-a291-4f9f-aacc-34c7c20e0b08_png.rf.9fe68187172328cd5304e6d144e48da4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/240_F_919779042_2J40rG0QlCFblfQd5wmm5O1j1lPG8po3_jpg.rf.91996eef3712acbb447b3bc796829684.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/64a7bd32-570f-42ca-b998-14a29745d28f_png.rf.d34b5ad3b87f4144eb1a772719fa274d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/781e5812-6061-4289-b703-814b19be500e_png.rf.2fb4fecae1a18ab615e8aaa2ad058698.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/operation-theatre10_jpg.rf.b496cc4579dea3700b88a1aed6fbf4c7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/33b527cf-5c07-4471-a1bb-c702c9151d00_png_jpg.rf.55b152bdcac2054d9a193cf630c54cad.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/tool_test58_jpg.rf.1c0667765850d88546aaf5acf26dfb4e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/3e57c016-2d58-42b6-8315-c7e886a9f2d0_png.rf.9b1fc246760693242998077fe6fe9257.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/hospital-bedroom-1-_png_jpg.rf.41de2260a53a5b73f2e533f836b748df.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/5dbfcf8b-fdf7-42ec-ae2a-e5841d7bc416_png_jpg.rf.4a98cf0fc7ba10cab3bed53f2be036c5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/best-view-hotel-shah_png_jpg.rf.e2a707982382876541e055cc3b75d49e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/hospital-room-interior_png_jpg.rf.c4a9d928b8f236b8c6be0cf5777e7e29.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/stylish-modern-sofa-design-compressed_png_jpg.rf.0562c25446427c27d3443274f48bc03c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/ekenaeset-3-seat-sofa-kilanda-light-beige__1109716_pe870182_s5_png_jpg.rf.f8a572aafae556c82daf6c264561692b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/bed_12_jpg.rf.ca81f5531495595d6e226529a0373725.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/562bb79f-fe36-4c11-a995-eea50bbf21b2_png.rf.cd92fed1aa926a8e3866b550d2421880.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/76950550-1-_png_jpg.rf.1954b81c0fa38fd49e2c63976c4bfff1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/tool_3_jpeg_jpg.rf.789a575d81cfac6e38acc26c5f9d788a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/f9289551-f2f2-4c1f-8f84-be062b654364_png.rf.cdb759cb217271a81bf98a339274b617.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/1-2-_png_jpg.rf.2338484e4cd730d27214bd264dfae7e3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/110842014_ecgtest_png_jpg.rf.47319bb6d6ca8e8fc9644bb15e21cf03.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/stock-photo-ekg-or-ecg-monitor-and-patient-bed-in-the-hospital-528928834_png_jpg.rf.73275bbdfb08ddc980de6d7f5ce85aa5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/4da8bd2d-ddeb-4c70-b6f5-570a1b7306ed_png.rf.89cc093db49f7906efe0d30fa4ca47e2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/c8c44c70-543a-4e1c-8ea0-7278c83e2211_png.rf.3780269f2bace4f1050926d5788b53d1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/19b33693-db65-46cd-912a-2dd4c8efeb46_jpeg.rf.f10d3544eeb59f390c88f0aa0e3d9646.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/f9f1140e-6cad-41f9-9e0e-ca7fd4a34a36_png_jpg.rf.8b884a9a4f7550f1d88476182abad52c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/eb799ac9-3279-4ae9-983f-5c3cb482b552_png_jpg.rf.36761c9dba3762b674417d8a11eb8edf.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/Roslin2strLS_png_jpg.rf.9174f37023022f51c2b286cf9e46449b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/kamalnayanbajaj_micu_mon-14_2022_6_20_0_46_26_jpeg_jpg.rf.acb7cbd70b4efd7f56d891287c18aaa7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/6c0906f6-4506-4727-ab75-7e01bdc2adbb_png.rf.27b65cdf875c710d07c336ed4d8b55cb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/tool_test22_jpeg_jpg.rf.37f9ee879283277a03ae239ded3d70c2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/3fc66247-24af-4e8d-bb3f-6affd977433d_png.rf.90446ebded2cefefe2c855353cae874f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/d818395e-3a8a-4e56-ac7e-578efc828d67_png_jpg.rf.e6b7c0947855e583cff41c88824ef882.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/2ef9ee14-8472-48e8-bca5-104c3f180617_png.rf.b1de590a3d46d9d2724ed89f5bed905c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/ECG-1_jpg.rf.b772b1d9e979b9496352cfed52d14e1c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/45a53259-7786-4984-8673-ac54b4968e18_png.rf.0dbad0a0b9f4b07f0731e13f6e9e41a6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/5cfd85da-d98e-4f9c-8874-8aaeb767d5d5_png_jpg.rf.15828fa8b2374033c561ff0b267ff530.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/bed_17_jpg.rf.9facb1355466a2df8d19afc83b94a83c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/825100a0-12f4-415a-bcfa-ae701d6413c7_png.rf.da0635668cc4979076009ee84dddb5d7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/tool_23_jpeg_jpg.rf.83a66e993d1f65523f9f6325fc192f90.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/8acc4082-04c0-470b-abe5-efc8a19055a7_png.rf.33938bf5636fef2a4eab7f38d051adfc.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/1933af90-7769-467d-81b4-a1364180efc4_jpeg.rf.5c62544396497e1fc1a30dad3a798b13.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/f914334fabd7f77fa2ea3eea68ee19e49db990b4-1400x1120_png_jpg.rf.40e800ea207571585178c88672bc9f02.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/41zdkJkvTSL-_AC-1-_png_jpg.rf.5f586230176b72f277306ab18216ff81.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/IMG_20220803_110201_jpg.rf.c81c290a038d6445ca340b4c9f31dc4b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/operation-theatre6_jpg.rf.7678837e1c2946753fb3d37c5bbaa89d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/bed-simple-hotel-hospital-260nw-224587435_png_jpg.rf.75eca4788fa35ce87dc71c36efed8c54.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/12-1-CH-Health-ECG-Monitor-Patient-Hospital-Patient-Monitor-Yk-8000c_png_jpg.rf.46e7b163cce250eea0b6011a9295e4ab.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/12-min-1_png_jpg.rf.ac7bdbee589d1f98bab1d5c70475a5eb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/hcgnagpur_icu_mon-4_2022_5_18_7_30_40_jpeg_jpg.rf.a5c9649c539185db4f93f7d614522378.jpg
# ...
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/92fa237b-32f5-4fb7-899c-00d8e11f63c2_png.rf.7de658c140ab5345097c62de8c5fea9d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/36869cc0-f1fa-4e2f-99b2-46cf9232f2c3_png.rf.24bfd0b0ae7ec4476f41395b773ae56c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/AstridO-11_png_jpg.rf.887285ea87a17e9b16b52be6c67550c0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/31KYnTMP7eL-_AC_UF1000-1000_QL80-1-_png_jpg.rf.ef11a4de785c476957a5050516a70f9c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_test24_jpeg_jpg.rf.a262b500927f88bd5017bebe9b3515c3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/3a678560-9c5a-4811-97af-503b69088a61_png.rf.e554c572a2cf95882866f72e0d9b72f4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/9a16afd5-81ac-4f7b-a317-aad2e9c0a81f_png.rf.9961e9b45157970c77d993cdfe061d7a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/electrocardiograma-552_png_jpg.rf.43f601c8dcc7147d5fbfbf968c8db687.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/41e9afb9-c2ac-4398-8f25-1f3c4919c238_png.rf.966508c1489df47465a370e2cf5dddca.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/a96c3dd4-b188-4976-b4f7-1e34bd46c0c8_png_jpg.rf.c027db4e118045eca9a0356d1d72a5ef.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/stool_9_jpeg.rf.f5fb5c81da5fad7531bc5c3578db2946.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_8_jpeg_jpg.rf.bc460c7193e717b5389d9830d3132d7a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-1-_png_jpg.rf.db0c9804016851704332b1ea47e8bb73.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/10c30d6a_png_jpg.rf.caf129316567a873c25864e257d8b54f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-18-_png_jpg.rf.8231095300e0181b7c3482d77e065c4c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/symmetrical-grey-chenille-no-tcplsofacumbedmolfinogrey5x6-sleep-original-imagugyfczekeqej_jpeg_jpg.rf.0d2703a1825b2512842682b4d7c36247.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/e366e1ad-2d35-4dc6-914e-7a44c3760654_png_jpg.rf.6ecf7c47995c28ffa90846888f2192d9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-56-_png_jpg.rf.49da3cd8e769df76a92fd10dcdbf90f6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/da7de394-ac62-4ad4-b282-b25520c71146_png_jpg.rf.e4f7af52c15a9e27f799c79f6e54ecc0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/blue-velvet-3-1-1-crete-311-flipkart-perfect-homes-blue-grey-original-imah2z3hfyqjfvkv_jpeg_jpg.rf.12858bdd920b2067e483f3ef38af899e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/3c785b82-a993-461e-91f8-32b74c1a88dd_png.rf.56b3ca06ac1b270d7294182d46195055.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_4_jpg.rf.df2efe7f218f278fe89e4ebbfb5f50c5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/c9f1712f-875c-4a27-bd95-2bacccc5a1a9_png.rf.a6a32ba0d25c975568650b0aa4da7b6d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/4d63881b-b4c1-4137-8629-bb42a96b55c7_png_jpg.rf.ffde588a02fca74a4fb33cd6d3c981b0.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/IMG_20220804_103726_jpg.rf.0ef77614d81ad5d7207f0a6cf32bb4f1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_test55_jpg.rf.e795693ec97cb2f030d0804230eb0189.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/Screenshot-12_jpg.rf.74a53178be4990330ab22a1ad6b0ac28.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/IMG_20220803_110214_jpg.rf.1b9f6e1bd0cb4fa90d9049acf7bcc539.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-2-_png_jpg.rf.44716b55e93ff92d4f157ee61c7f661d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/3830118a-90c1-4045-a6df-cd532d295b90_png.rf.bdb8876c86dedf06ccabd6901e98207c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/476eeda6-17d6-45b0-b131-b13751b31f12_png.rf.97add5325d5c1b959be6f234125273e2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/73da5087-20a3-4734-b3dd-116456a66896_jpeg.rf.9c6239f838ced9c42f43019462e5e34b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/gurney-in-empty-hospital-corridor_png_jpg.rf.0a96c7187de89cdff2e5b392d7727469.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_test12_jpg.rf.4f8f272f05b7c9146b6d7089369f795b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/6631a055-a2bb-422b-a677-575ab741ca1a_png.rf.c0faaa48c23f087e3625191e785eed96.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/0bed4026-ee00-4664-99a7-e73d9fb5fe56_png.rf.bf9b72cf984a938a3b6d29ec1dc2c7fb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-16-_png_jpg.rf.2349829b321fee681736d93861aa0917.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/IMG_20220804_103730_jpg.rf.cc2637fa99b4bd56a2a7a653b953781a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/d27714d1-be16-4b44-a285-e853df9ec858_png.rf.fbc6daba5ae654f592ff5e58053a051d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/4eec4e49-72fb-4e79-bdfc-d23e2be3a048_png.rf.ed00ee85b6f14e85737e13a4711e2038.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/pexels-photo-3769151_jpeg_jpg.rf.5456ede6678cbec58b5a0f5a345a3fec.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/71peaqU-lsL_png_jpg.rf.7657b3229dfccd02f672946d2125a0dc.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/MPDeluxe-Room-Taj-Club-House_png_jpg.rf.83450bd6f326e7b93554ebd38ad369be.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/6b75758c-28a6-4cf4-b569-41c3754a9612_png.rf.d5af51be93ee0a581ef2745f85b9b306.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/360_F_863843889_4cx3EppgTtHcYjCyIPslfslcN53B6xgk_jpg.rf.4053dfc223764d139f70229119747973.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_test49_jpg.rf.0f2a1baa0daf293df5e935ebe84a3d07.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/525d2c2e-524e-4524-95b8-cd8ac4278a5e_png_jpg.rf.d2fb130ae7d42ba4f67dba7b2de76349.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/e5f6c75d-ecb4-4c0a-8e28-5334cae2f7d8_png_jpg.rf.ad5f678c838b6721ab6a2a613a9233a9.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/208b48a9-7a6e-4db1-bef7-d44f27574433_png.rf.9e6429925e60a6629141d68d22b38411.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/hcgnagpur_icu_mon-4_2022_6_20_15_30_12_jpeg_jpg.rf.96a0885b25a603ab6ae93241baa7f6a2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/97f9e645ee4472dd38a02232417fb0db_a4baa0e6-a566-483f-b479-fcc7f95ff4f7_1024x1024_png_jpg.rf.affca5ff1e601ec4ac83f29d3d5d07ca.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/22faf9b2-8aa4-47c4-8207-78ab96d7a342_png.rf.be3346d4e2974f1ce58bc865281b1fc2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/Screenshot3_jpg.rf.edaae9e3282f31cb9516b6258d9f3089.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/H598fb849e1e543528cc6e61987f27a47u_png_jpg.rf.a226f0039663123cd3c523c85f30bf4a.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/46d43975-50fe-4187-898b-c906e7fa836a_png.rf.bd4182b8d270c3193c598035c9a6acbe.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/clinic-hospital-monitors-health-nurse-preparing-male-patient-for-ecg-test-video_png_jpg.rf.11a12b10e01115c7a6443cfa3595a1c2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/73da5087-20a3-4734-b3dd-116456a66896_jpeg.rf.6190c7e7cd97bb92b82c447201307b42.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/ELLIEScandinavianSofaJapaneseNordicStyleFullWoodFrame23-Copy_782x589_png_jpg.rf.ff84e72a61380c9639940c852f474173.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-28-_png_jpg.rf.284cb79d0cc3b0a0b4fea0f6431902ff.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/FNSF51RASF3_-_main_1_png_jpg.rf.b9be33c86057ecf1535de7dabd6215fd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/56101502SD01899_A2_803x602_png_jpg.rf.5210f1cbe26d5851ee9c954faf63911d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/4d63881b-b4c1-4137-8629-bb42a96b55c7_png_jpg.rf.fece32b2212f4aaf519d62dec7125f12.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/66aee2a3-4810-4a3c-a8d6-db6a6e1f9f43_png.rf.07055bba1fb132dc3fb511668b5e22f7.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/gurney-in-empty-hospital-corridor_png_jpg.rf.391b231acd30f48287eab03e2481d5f1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/kamalnayanbajaj_micu_mon-16_2022_6_20_5_46_47_jpeg_jpg.rf.19b63c9c0ecbc5cc027e633cd9ba2e8e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-10-_png_jpg.rf.801840771f13048918b79571bea2fba6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1000_F_649019465_69A7AUi0eAEPKkcVxzAmpFStWZckEGXh_jpg.rf.00e1d8f527d4a89e40bfa35b76a6fca2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/wide-angle-photo-of-empty-hospital-room-with-bed_png_jpg.rf.7e50105135c6a590e5d006e11e7b4fcf.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1000_F_559160698_O95ukcOnQUS7z4Xn9EAoqfJ7gREt6i8R_jpg.rf.1e3686386cc87090320961484d15c8a1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/91a795be-bdef-4ae6-b9f5-f60ce74ac062_png.rf.ddd0c6eeaaf3a7269d523e7f9fadfcd3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/360_F_785613160_mxBnZcP13IVqYPdJprOymOU9cjeUUXxC_png_jpg.rf.8b57828bcfdcd3120587fb909db2807b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/715c4065-637f-4a17-bf1e-a378ee23a357_png_jpg.rf.831906cc3e01491af0c898f67ccea8ed.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/43765f87-986b-4fc5-b1ef-8f41939a401a_png_jpg.rf.f2d63de9a0b921bcc01c2a53d26e8927.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/hcgnagpur_icu_mon-4_2022_5_18_3_30_40_jpeg_jpg.rf.d0208f2c428268b97078dc5d95568e38.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/91dfd48c-76fa-4626-a1ef-931f0ad94286_png.rf.7d61f9212dbe2877d8c4e18af624dd32.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_test_jpg.rf.7c0df98807717d4636725d33d03e4359.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/IMG_20220803_110634_jpg.rf.875d6832df3c608a8c2b666f8a2ec2ae.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/968288e2-857e-4066-bb02-8ee3f4e0bcea_png.rf.6b4a41c2a1aa78f86548f4ac8802f16d.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/torque-liana-5-seater-fabric-sofa-set-for-living-room-bedroom-office-furniture-32-seater-188786_png_jpg.rf.23abc5bccec2079b9aeed8bda0d232ed.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/ECG-2-_png_jpg.rf.4774ef168882de070067b3bf6d4e8769.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/hcgnagpur_icu_mon-2_2022_6_20_20_30_12_jpeg_jpg.rf.294bb9d81f473f7c96c595c560d869c1.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_6_jpeg_jpg.rf.4999705d94e95ac5570ebf0c6c84611c.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/6631a055-a2bb-422b-a677-575ab741ca1a_png.rf.ef1d4f9a805828e5a365b6efbe615a97.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/operation-theatre5_jpg.rf.dc701c36115a61801f044729ca12f38e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/ecg-machine-of-a-heart-hospital-P0NC7G_png_jpg.rf.b4d7fc059222d402b8f607562186c4d4.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/e2cdc78b-f697-4c5d-9145-9e06c0d3f699_png.rf.e485fc6e883695a9c0cf8f9034e39041.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/615b3f85-ee28-4f11-ad6c-3f7cab5e6933_png.rf.569a00088189256cbc976bc9f021be84.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/e453b71c-64ed-4261-9388-1551c034b6ba_png_jpg.rf.39054c05242bf3c1e65949535d5b9936.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/5238ff2f-afc6-460c-b12c-0225c1ec2a62_png_jpg.rf.3649109fa0af50166e2a3b62f2b9a1b5.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/tool_48_jpeg_jpg.rf.4fcdb207b1a78c5c70b79d562e83dfeb.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-5-_png_jpg.rf.659e1e896e84e428875074ce99167f8f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/hcgnagpur_icu_mon-3_2022_5_18_2_30_28_jpeg_jpg.rf.e1fd1245af5832956fb040127aabe173.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/stool_5_jpeg.rf.5fae82b092f2e2fe7f9be93f1f5a756b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1f490fb7-1927-4ee9-aa41-793ac16f0a3d_png.rf.e39d1398adeb33d35bbaac83f2836c00.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/patient-hospital-bed-ecg-monitor-room-318012727_png_jpg.rf.1cab4e118ad765b98f5e220e1022ebc2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-39-_png_jpg.rf.45ab8847a087ad4535c7f032796364c3.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/41588373-32dd-4f8a-bb67-b38376b93406_jpeg.rf.9dfdaab9a83e09aacd76f274068da30b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1a662907-b7da-4934-a919-a1eef4ee3fe0_png.rf.72311596462a51f0353bb09898594907.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/ECG-7_jpg.rf.56ae2763f1529e1f9cb7fe436f584857.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-3-_png_jpg.rf.27c9cf9762b9a0306d969dd2876b21cd.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/Hospital_test_jpg.rf.c032ddaacf4eeb5a485c9d26a981e0e2.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1000_F_804709382_xen2ptVSe6ED7krLU7h9qwNSobOxxT7n_jpg.rf.c55ca022c60d091b8e4204952bddafc6.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/perspective-view-of-hospital-single-patient-room-fully-furnished_png_jpg.rf.a406371a29c751390650de5c9c8bbc78.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/1000_F_284178160_3wdhfG9Wj6cxQqMAyLHMRwBIhGDqyLBr_png_jpg.rf.21e3a3795d1c4d792287a82f6f3bca29.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/40010102-f193-45f9-8db0-faec002adfaa_png.rf.99af0abf3f845ff324d3044389cadf69.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/ELLIEScandinavianSofaJapaneseNordicStyleFullWoodFrame13_790x950_png_jpg.rf.587e980a98f55c5a001687509b04e160.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-48-_png_jpg.rf.eaa18cbd4a73ff4d03a10636342e8bdc.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/IMG_20220804_103908_jpg.rf.972a9cef496063257e4752c21c6cc92b.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/images-1-_png_jpg.rf.bcdeb56c09479ab3966ed22e94556503.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/hcgnagpur_icu_mon-4_2022_6_20_6_30_24_jpeg_jpg.rf.8202fac160785af487a54ae18b36091f.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/95e2e534-2ebe-41f7-964a-dc4c883e1792_png.rf.1bdefc882364cc8f38be3eb819e3060e.jpg
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/marquette-12sl-hero-mobile_png_jpg.rf.3d4c51f0a1e23b9bb3ccc7c19c17a241.jpg

# %%
import os
import json
import random
from collections import Counter, defaultdict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torchvision
from torchvision.transforms import functional as F
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
print("Torch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
# Out:
# Using device: cuda
# Torch version: 2.9.0+cu126
# Torchvision version: 0.24.0+cu126

# %%
DATASET_ROOT = "/kaggle/input/datasets/georgelukaanya/hospitalcocoversion"

TRAIN_IMG_DIR = os.path.join(DATASET_ROOT, "train")
VAL_IMG_DIR   = os.path.join(DATASET_ROOT, "valid")
TEST_IMG_DIR  = os.path.join(DATASET_ROOT, "test")

TRAIN_JSON = os.path.join(TRAIN_IMG_DIR, "_annotations.coco.json")
VAL_JSON   = os.path.join(VAL_IMG_DIR, "_annotations.coco.json")
TEST_JSON  = os.path.join(TEST_IMG_DIR, "_annotations.coco.json")

print(TRAIN_JSON)
print(VAL_JSON)
print(TEST_JSON)
# Out:
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/train/_annotations.coco.json
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/valid/_annotations.coco.json
# /kaggle/input/datasets/georgelukaanya/hospitalcocoversion/test/_annotations.coco.json

# %%
with open(TRAIN_JSON, "r") as f:
    train_coco = json.load(f)

with open(VAL_JSON, "r") as f:
    val_coco = json.load(f)

with open(TEST_JSON, "r") as f:
    test_coco = json.load(f)

print("Train images:", len(train_coco["images"]))
print("Val images:", len(val_coco["images"]))
print("Test images:", len(test_coco["images"]))
print("Train annotations:", len(train_coco["annotations"]))
# Out:
# Train images: 5195
# Val images: 272
# Test images: 146
# Train annotations: 8745

# %%
cat_id_to_name = {cat["id"]: cat["name"] for cat in train_coco["categories"]}
cat_name_to_id = {cat["name"]: cat["id"] for cat in train_coco["categories"]}

train_class_counts = Counter(ann["category_id"] for ann in train_coco["annotations"])

class_df = pd.DataFrame([
    {
        "class_id": cid,
        "class_name": cat_id_to_name[cid],
        "train_count": train_class_counts.get(cid, 0)
    }
    for cid in sorted(cat_id_to_name.keys())
]).sort_values("train_count", ascending=False).reset_index(drop=True)

display(class_df)

plt.figure(figsize=(10, 5))
plt.bar(class_df["class_name"], class_df["train_count"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("Annotation Count")
plt.title("Training Class Distribution")
plt.tight_layout()
plt.show()

nonzero_counts = class_df[class_df["train_count"] > 0]["train_count"]
print("Imbalance ratio:", round(nonzero_counts.max() / nonzero_counts.min(), 2), ":1")
# Out:
#    class_id    class_name  train_count
# 0         1       Monitor         2185
# 1         3           bed         1930
# 2         6          sofa         1285
# 3         8   tools_table          895
# 4         7         stool          850
# 5         2  Saline Stand          770
# 6         5         chair          720
# 7         4           bin          110
# 8         0          tool            0
# Imbalance ratio: 19.86 :1

# %%
train_image_id_to_anns = defaultdict(list)
for ann in train_coco["annotations"]:
    train_image_id_to_anns[ann["image_id"]].append(ann)

train_images = train_coco["images"]

# inverse frequency class weights
class_weights = {}
for cid in cat_id_to_name.keys():
    count = train_class_counts.get(cid, 0)
    class_weights[cid] = 1.0 / count if count > 0 else 0.0

# normalize weights
nonzero = [w for w in class_weights.values() if w > 0]
mean_w = np.mean(nonzero)
for cid in class_weights:
    if class_weights[cid] > 0:
        class_weights[cid] /= mean_w

# assign image weights based on rarest class in image
image_weights = []
for img in train_images:
    img_id = img["id"]
    anns = train_image_id_to_anns[img_id]
    if len(anns) == 0:
        image_weights.append(1.0)
    else:
        img_weight = max(class_weights[ann["category_id"]] for ann in anns)
        image_weights.append(img_weight)

image_weights = np.array(image_weights, dtype=np.float32)

print("Image weights summary")
print("Min:", image_weights.min())
print("Max:", image_weights.max())
print("Mean:", image_weights.mean())
# Out:
# Image weights summary
# Min: 0.2313445
# Max: 4.595343
# Mean: 0.51593053

# %%
class HospitalCocoDetectionDataset(Dataset):
    def __init__(self, coco_dict, img_dir, train=False):
        self.coco = coco_dict
        self.img_dir = img_dir
        self.train = train

        self.images = coco_dict["images"]
        self.annotations = coco_dict["annotations"]
        self.categories = coco_dict["categories"]

        self.image_id_to_anns = defaultdict(list)
        for ann in self.annotations:
            self.image_id_to_anns[ann["image_id"]].append(ann)

        self.cat_ids = sorted([cat["id"] for cat in self.categories])
        self.cat_id_to_label = {cat_id: i + 1 for i, cat_id in enumerate(self.cat_ids)}
        self.label_to_cat_id = {v: k for k, v in self.cat_id_to_label.items()}

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_info = self.images[idx]
        img_id = img_info["id"]
        img_path = os.path.join(self.img_dir, img_info["file_name"])

        image = Image.open(img_path).convert("RGB")
        image = F.to_tensor(image)

        anns = self.image_id_to_anns[img_id]

        boxes = []
        labels = []
        areas = []
        iscrowd = []

        for ann in anns:
            x, y, w, h = ann["bbox"]

            if w <= 1 or h <= 1:
                continue

            boxes.append([x, y, x + w, y + h])
            labels.append(self.cat_id_to_label[ann["category_id"]])
            areas.append(w * h)
            iscrowd.append(ann.get("iscrowd", 0))

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        areas = torch.as_tensor(areas, dtype=torch.float32)
        iscrowd = torch.as_tensor(iscrowd, dtype=torch.int64)

        target = {
            "boxes": boxes,
            "labels": labels,
            "image_id": torch.tensor([img_id]),
            "area": areas,
            "iscrowd": iscrowd
        }

        if self.train:
            image, target = self.apply_transforms(image, target)

        return image, target

    def apply_transforms(self, image, target):
        _, h, w = image.shape

        # horizontal flip
        if random.random() < 0.5:
            image = torch.flip(image, dims=[2])
            boxes = target["boxes"].clone()
            boxes[:, [0, 2]] = w - boxes[:, [2, 0]]
            target["boxes"] = boxes

        # mild brightness / contrast jitter
        if random.random() < 0.3:
            image = F.adjust_brightness(image, random.uniform(0.9, 1.1))
            image = F.adjust_contrast(image, random.uniform(0.9, 1.1))

        return image, target

# %%
train_dataset = HospitalCocoDetectionDataset(train_coco, TRAIN_IMG_DIR, train=True)
val_dataset   = HospitalCocoDetectionDataset(val_coco, VAL_IMG_DIR, train=False)
test_dataset  = HospitalCocoDetectionDataset(test_coco, TEST_IMG_DIR, train=False)

def collate_fn(batch):
    return tuple(zip(*batch))

train_sampler = WeightedRandomSampler(
    weights=torch.DoubleTensor(image_weights),
    num_samples=len(image_weights),
    replacement=True
)

train_loader = DataLoader(
    train_dataset,
    batch_size=2,
    sampler=train_sampler,
    num_workers=2,
    collate_fn=collate_fn
)

val_loader = DataLoader(
    val_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    test_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=2,
    collate_fn=collate_fn
)

print("Train batches:", len(train_loader))
print("Val batches:", len(val_loader))
print("Test batches:", len(test_loader))
# Out:
# Train batches: 2598
# Val batches: 136
# Test batches: 73

# %%
num_hospital_classes = len(train_coco["categories"])
num_classes = num_hospital_classes + 1  # +1 for background

model = fasterrcnn_resnet50_fpn(weights="DEFAULT")

in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

model.to(device)
print("Model ready. Number of classes including background:", num_classes)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 200MB/s]
# Model ready. Number of classes including background: 10

# %%
params = [p for p in model.parameters() if p.requires_grad]

optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=5,
    gamma=0.1
)

# %%
def train_one_epoch(model, loader, optimizer, device):
    model.train()
    running_loss = 0.0

    for images, targets in loader:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        running_loss += losses.item()

    return running_loss / len(loader)

# %%
@torch.no_grad()
def validate_one_epoch(model, loader, device):
    model.train()
    running_loss = 0.0

    for images, targets in loader:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        running_loss += losses.item()

    return running_loss / len(loader)

# %%
num_epochs = 10

train_losses = []
val_losses = []
best_val_loss = float("inf")
best_model_path = "/kaggle/working/best_faster_rcnn.pth"

for epoch in range(num_epochs):
    train_loss = train_one_epoch(model, train_loader, optimizer, device)
    val_loss = validate_one_epoch(model, val_loader, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    lr_scheduler.step()

    print(f"Epoch {epoch+1}/{num_epochs}")
    print(f"  Train Loss: {train_loss:.4f}")
    print(f"  Val Loss:   {val_loss:.4f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), best_model_path)
        print("  Saved best model.")

print("Training complete.")
print("Best model saved to:", best_model_path)
# Out:
# Epoch 1/10
#   Train Loss: 0.1970
#   Val Loss:   0.1840
#   Saved best model.
# Epoch 2/10
#   Train Loss: 0.1009
#   Val Loss:   0.1523
#   Saved best model.
# Epoch 3/10
#   Train Loss: 0.0775
#   Val Loss:   0.1763
# Epoch 4/10
#   Train Loss: 0.0722
#   Val Loss:   0.1616
# Epoch 5/10
#   Train Loss: 0.0663
#   Val Loss:   0.1593
# Epoch 6/10
#   Train Loss: 0.0386
#   Val Loss:   0.1649
# Epoch 7/10
#   Train Loss: 0.0330
#   Val Loss:   0.1653
# Epoch 8/10
#   Train Loss: 0.0306
#   Val Loss:   0.1693
# Epoch 9/10
#   Train Loss: 0.0299
#   Val Loss:   0.1764
# Epoch 10/10
#   Train Loss: 0.0279
#   Val Loss:   0.1703
# Training complete.
# Best model saved to: /kaggle/working/best_faster_rcnn.pth

# %%
plt.figure(figsize=(8, 5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Faster R-CNN Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
model.load_state_dict(torch.load(best_model_path, map_location=device))
model.to(device)
model.eval()
print("Loaded best model.")
# Out:
# Loaded best model.

# %%
def compute_iou(box1, box2):
    xA = max(box1[0], box2[0])
    yA = max(box1[1], box2[1])
    xB = min(box1[2], box2[2])
    yB = min(box1[3], box2[3])

    inter_w = max(0, xB - xA)
    inter_h = max(0, yB - yA)
    inter_area = inter_w * inter_h

    area1 = max(0, box1[2] - box1[0]) * max(0, box1[3] - box1[1])
    area2 = max(0, box2[2] - box2[0]) * max(0, box2[3] - box2[1])

    union = area1 + area2 - inter_area
    return inter_area / union if union > 0 else 0.0

# %%
label_to_cat_id = train_dataset.label_to_cat_id

@torch.no_grad()
def evaluate_per_class_recall(model, loader, device, score_thresh=0.5, iou_thresh=0.5):
    model.eval()

    gt_counts = Counter()
    tp_counts = Counter()

    for images, targets in loader:
        images = [img.to(device) for img in images]
        outputs = model(images)

        for output, target in zip(outputs, targets):
            gt_boxes = target["boxes"].numpy()
            gt_labels = target["labels"].numpy()

            pred_boxes = output["boxes"].cpu().numpy()
            pred_labels = output["labels"].cpu().numpy()
            pred_scores = output["scores"].cpu().numpy()

            keep = pred_scores >= score_thresh
            pred_boxes = pred_boxes[keep]
            pred_labels = pred_labels[keep]

            used_preds = set()

            for gt_idx, (gt_box, gt_label) in enumerate(zip(gt_boxes, gt_labels)):
                gt_counts[gt_label] += 1

                best_iou = 0.0
                best_pred_idx = -1

                for pred_idx, (pred_box, pred_label) in enumerate(zip(pred_boxes, pred_labels)):
                    if pred_idx in used_preds:
                        continue
                    if pred_label != gt_label:
                        continue

                    iou = compute_iou(gt_box, pred_box)
                    if iou > best_iou:
                        best_iou = iou
                        best_pred_idx = pred_idx

                if best_iou >= iou_thresh and best_pred_idx != -1:
                    tp_counts[gt_label] += 1
                    used_preds.add(best_pred_idx)

    rows = []
    for label, gt_count in sorted(gt_counts.items()):
        tp = tp_counts.get(label, 0)
        recall = tp / gt_count if gt_count > 0 else 0.0
        cat_id = label_to_cat_id[label]
        rows.append({
            "label": label,
            "class_name": cat_id_to_name[cat_id],
            "gt_count": gt_count,
            "tp": tp,
            "recall": recall
        })

    return pd.DataFrame(rows).sort_values("recall", ascending=True)

# %%
recall_df = evaluate_per_class_recall(
    model,
    val_loader,
    device,
    score_thresh=0.5,
    iou_thresh=0.5
)

display(recall_df)
# Out:
#    label    class_name  gt_count  tp    recall
# 2      4           bed        80  59  0.737500
# 7      9   tools_table        47  37  0.787234
# 0      2       Monitor       102  82  0.803922
# 4      6         chair        36  29  0.805556
# 5      7          sofa        64  53  0.828125
# 1      3  Saline Stand        41  35  0.853659
# 6      8         stool        44  40  0.909091
# 3      5           bin         2   2  1.000000

# %%
import matplotlib.patches as patches

def show_predictions(model, dataset, index=0, score_thresh=0.5):
    model.eval()

    image, target = dataset[index]
    image_device = image.to(device)

    with torch.no_grad():
        output = model([image_device])[0]

    image_np = image.permute(1, 2, 0).cpu().numpy()

    fig, ax = plt.subplots(1, 2, figsize=(16, 8))

    # Ground truth
    ax[0].imshow(image_np)
    ax[0].set_title("Ground Truth")
    for box, label in zip(target["boxes"], target["labels"]):
        x1, y1, x2, y2 = box.numpy()
        rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, fill=False, linewidth=2)
        ax[0].add_patch(rect)
        class_name = cat_id_to_name[label_to_cat_id[label.item()]]
        ax[0].text(x1, y1, class_name, fontsize=10, bbox=dict(facecolor="yellow", alpha=0.5))

    # Predictions
    ax[1].imshow(image_np)
    ax[1].set_title("Predictions")
    boxes = output["boxes"].cpu().numpy()
    labels = output["labels"].cpu().numpy()
    scores = output["scores"].cpu().numpy()

    for box, label, score in zip(boxes, labels, scores):
        if score < score_thresh:
            continue
        x1, y1, x2, y2 = box
        rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, fill=False, linewidth=2)
        ax[1].add_patch(rect)
        class_name = cat_id_to_name[label_to_cat_id[label]]
        ax[1].text(x1, y1, f"{class_name} {score:.2f}", fontsize=10,
                   bbox=dict(facecolor="cyan", alpha=0.5))

    plt.tight_layout()
    plt.show()

# %%
show_predictions(model, val_dataset, index=0, score_thresh=0.5)

# %%
final_model_path = "/kaggle/working/faster_rcnn_final.pth"
torch.save(model.state_dict(), final_model_path)

recall_df.to_csv("/kaggle/working/val_per_class_recall.csv", index=False)

print("Saved:")
print(final_model_path)
print("/kaggle/working/val_per_class_recall.csv")
# Out:
# Saved:
# /kaggle/working/faster_rcnn_final.pth
# /kaggle/working/val_per_class_recall.csv

# %%
# !pip install -q torchmetrics

# %%
from torchmetrics.detection.mean_ap import MeanAveragePrecision

# %%
@torch.no_grad()
def evaluate_map(model, loader, device):
    model.eval()
    
    metric = MeanAveragePrecision(
        box_format="xyxy",
        iou_type="bbox",
        class_metrics=True
    )

    for images, targets in loader:
        images = [img.to(device) for img in images]
        outputs = model(images)

        preds = []
        gts = []

        for output, target in zip(outputs, targets):
            preds.append({
                "boxes": output["boxes"].cpu(),
                "scores": output["scores"].cpu(),
                "labels": output["labels"].cpu()
            })

            gts.append({
                "boxes": target["boxes"].cpu(),
                "labels": target["labels"].cpu()
            })

        metric.update(preds, gts)

    results = metric.compute()
    return results

# %%
map_results = evaluate_map(model, val_loader, device)

for k, v in map_results.items():
    print(k, v)
# Out:
# map tensor(0.5453)
# map_50 tensor(0.7850)
# map_75 tensor(0.6399)
# map_small tensor(0.)
# map_medium tensor(0.1792)
# map_large tensor(0.5859)
# mar_1 tensor(0.6175)
# mar_10 tensor(0.7007)
# mar_100 tensor(0.7007)
# mar_small tensor(0.)
# mar_medium tensor(0.2214)
# mar_large tensor(0.7068)
# map_per_class tensor([0.4535, 0.6206, 0.5721, 0.3254, 0.5697, 0.6846, 0.7182, 0.4183])
# mar_100_per_class tensor([0.5843, 0.7195, 0.6925, 0.7500, 0.6444, 0.7734, 0.8205, 0.6213])
# classes tensor([2, 3, 4, 5, 6, 7, 8, 9], dtype=torch.int32)

# %%
@torch.no_grad()
def evaluate_per_class_metrics(model, loader, device, score_thresh=0.5, iou_thresh=0.5):
    model.eval()

    gt_counts = Counter()
    tp_counts = Counter()
    fp_counts = Counter()

    for images, targets in loader:
        images = [img.to(device) for img in images]
        outputs = model(images)

        for output, target in zip(outputs, targets):
            gt_boxes = target["boxes"].numpy()
            gt_labels = target["labels"].numpy()

            pred_boxes = output["boxes"].cpu().numpy()
            pred_labels = output["labels"].cpu().numpy()
            pred_scores = output["scores"].cpu().numpy()

            keep = pred_scores >= score_thresh
            pred_boxes = pred_boxes[keep]
            pred_labels = pred_labels[keep]

            matched_gt = set()

            for gt_box, gt_label in zip(gt_boxes, gt_labels):
                gt_counts[gt_label] += 1

            for pred_idx, (pred_box, pred_label) in enumerate(zip(pred_boxes, pred_labels)):
                best_iou = 0.0
                best_gt_idx = -1

                for gt_idx, (gt_box, gt_label) in enumerate(zip(gt_boxes, gt_labels)):
                    if gt_idx in matched_gt:
                        continue
                    if gt_label != pred_label:
                        continue

                    iou = compute_iou(gt_box, pred_box)
                    if iou > best_iou:
                        best_iou = iou
                        best_gt_idx = gt_idx

                if best_iou >= iou_thresh and best_gt_idx != -1:
                    tp_counts[pred_label] += 1
                    matched_gt.add(best_gt_idx)
                else:
                    fp_counts[pred_label] += 1

    rows = []
    all_labels = sorted(set(list(gt_counts.keys()) + list(tp_counts.keys()) + list(fp_counts.keys())))

    for label in all_labels:
        tp = tp_counts.get(label, 0)
        fp = fp_counts.get(label, 0)
        gt = gt_counts.get(label, 0)
        fn = gt - tp

        precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        recall = tp / gt if gt > 0 else 0.0
        f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0.0
        fnr = fn / gt if gt > 0 else 0.0

        cat_id = label_to_cat_id[label]
        rows.append({
            "label": label,
            "class_name": cat_id_to_name[cat_id],
            "gt_count": gt,
            "tp": tp,
            "fp": fp,
            "fn": fn,
            "precision": precision,
            "recall": recall,
            "f1_score": f1,
            "false_negative_rate": fnr
        })

    return pd.DataFrame(rows).sort_values("recall")

# %%
metrics_df = evaluate_per_class_metrics(
    model,
    val_loader,
    device,
    score_thresh=0.5,
    iou_thresh=0.5
)

display(metrics_df)
# Out:
#    label    class_name  gt_count  tp  fp  fn  precision    recall  f1_score  \
# 2      4           bed        80  59  13  21   0.819444  0.737500  0.776316
# 7      9   tools_table        47  37  22  10   0.627119  0.787234  0.698113
# 0      2       Monitor       102  82  53  20   0.607407  0.803922  0.691983
# 4      6         chair        36  29   6   7   0.828571  0.805556  0.816901
# 5      7          sofa        64  53   4  11   0.929825  0.828125  0.876033
# 1      3  Saline Stand        41  35  46   6   0.432099  0.853659  0.573770
# 6      8         stool        44  40  21   4   0.655738  0.909091  0.761905
# 3      5           bin         2   2   3   0   0.400000  1.000000  0.571429
#
#    false_negative_rate
# 2             0.262500
# 7             0.212766
# 0             0.196078
# 4             0.194444
# 5             0.171875
# 1             0.146341
# 6             0.090909
# 3             0.000000

# %%
import time

@torch.no_grad()
def measure_inference_speed(model, loader, device, num_batches=20):
    model.eval()
    times = []

    for i, (images, _) in enumerate(loader):
        if i >= num_batches:
            break

        images = [img.to(device) for img in images]

        torch.cuda.synchronize() if torch.cuda.is_available() else None
        start = time.time()

        _ = model(images)

        torch.cuda.synchronize() if torch.cuda.is_available() else None
        end = time.time()

        times.append(end - start)

    avg_time = np.mean(times)
    fps = 1.0 / avg_time if avg_time > 0 else 0.0

    return {
        "avg_time_per_batch_sec": avg_time,
        "fps_estimate": fps
    }

# %%
speed_results = measure_inference_speed(model, val_loader, device)

print(speed_results)
# Out:
# {'avg_time_per_batch_sec': np.float64(0.09540414810180664), 'fps_estimate': np.float64(10.481724536053619)}
